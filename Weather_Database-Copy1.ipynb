# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 716

# %%
len(cities)
# Out:
# 716

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | iracoubo
# Processing Record 8 of Set 1 | camalu
# Processing Record 9 of Set 1 | katsuura
# Processing Record 10 of Set 1 | guerrero negro
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | coquimbo
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | ahipara
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | anamur
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | galle
# Processing Record 24 of Set 1 | berlevag
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | qaqortoq
# Processing Record 28 of Set 1 | nueva granada
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | zhuozhou
# City not found. Skipping...
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | maputo
# Processing Record 34 of Set 1 | baiyin
# Processing Record 35 of Set 1 | rabo de peixe
# Processing Record 36 of Set 1 | esna
# Processing Record 37 of Set 1 | ankang
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | saint-augustin
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | hoa binh
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | teya
# Processing Record 48 of Set 1 | mandalgovi
# Processing Record 49 of Set 1 | laguna
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | okha
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | prince rupert
# Processing Record 5 of Set 2 | bandar-e anzali
# Processing Record 6 of Set 2 | lebanon
# Processing Record 7 of Set 2 | karratha
# Processing Record 8 of Set 2 | misratah
# Processing Record 9 of Set 2 | mount isa
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | pacific grove
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | verkhoyansk
# Processing Record 16 of Set 2 | buin
# Processing Record 17 of Set 2 | avallon
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | oldenzaal
# Processing Record 20 of Set 2 | verkhnevilyuysk
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | ovalle
# Processing Record 23 of Set 2 | santa rosalia
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | sibolga
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | la orilla
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | mundo nuevo
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | san cristobal
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | havoysund
# Processing Record 38 of Set 2 | port hedland
# Processing Record 39 of Set 2 | zhigansk
# Processing Record 40 of Set 2 | haines junction
# Processing Record 41 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | camopi
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | elizabeth city
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | otradnoye
# Processing Record 50 of Set 2 | dicabisagan
# Processing Record 1 of Set 3 | grand island
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | gushikawa
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 9 of Set 3 | kieta
# Processing Record 10 of Set 3 | batemans bay
# Processing Record 11 of Set 3 | marsa matruh
# Processing Record 12 of Set 3 | broska
# Processing Record 13 of Set 3 | banda aceh
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | saint-francois
# Processing Record 17 of Set 3 | hay river
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | arlit
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | boende
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | letterkenny
# Processing Record 28 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | madras
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | den helder
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | karjat
# Processing Record 36 of Set 3 | sri aman
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | jawa
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | auki
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | north platte
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | okhotsk
# Processing Record 49 of Set 3 | geraldton
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | kahului
# Processing Record 5 of Set 4 | ambunti
# Processing Record 6 of Set 4 | lukovetskiy
# Processing Record 7 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 4 | gigmoto
# Processing Record 9 of Set 4 | chicama
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | mokrousovo
# Processing Record 12 of Set 4 | homer
# Processing Record 13 of Set 4 | huntsville
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | zolotonosha
# Processing Record 16 of Set 4 | kautokeino
# Processing Record 17 of Set 4 | vestmanna
# Processing Record 18 of Set 4 | zyryanka
# Processing Record 19 of Set 4 | simao
# Processing Record 20 of Set 4 | bucerias
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | shepsi
# Processing Record 23 of Set 4 | mahebourg
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | bama
# Processing Record 26 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 4 | quelimane
# Processing Record 28 of Set 4 | kaeo
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | takestan
# Processing Record 31 of Set 4 | adwa
# Processing Record 32 of Set 4 | erenhot
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 35 of Set 4 | comodoro rivadavia
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | solnechnyy
# Processing Record 39 of Set 4 | aklavik
# Processing Record 40 of Set 4 | clyde river
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | wana
# Processing Record 44 of Set 4 | jiangyou
# Processing Record 45 of Set 4 | port macquarie
# Processing Record 46 of Set 4 | leczyca
# Processing Record 47 of Set 4 | vawkavysk
# Processing Record 48 of Set 4 | najran
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | newcastle
# Processing Record 1 of Set 5 | betsiamites
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | alcala la real
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | vylok
# Processing Record 6 of Set 5 | sao joao do piaui
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 5 | cravo norte
# Processing Record 10 of Set 5 | portland
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | itaporanga
# Processing Record 13 of Set 5 | kurilsk
# Processing Record 14 of Set 5 | igarka
# Processing Record 15 of Set 5 | tigil
# Processing Record 16 of Set 5 | yar-sale
# Processing Record 17 of Set 5 | huarmey
# Processing Record 18 of Set 5 | chengmai
# City not found. Skipping...
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | grafton
# Processing Record 21 of Set 5 | urengoy
# Processing Record 22 of Set 5 | hambantota
# Processing Record 23 of Set 5 | matagami
# Processing Record 24 of Set 5 | diamantina
# Processing Record 25 of Set 5 | garden city
# Processing Record 26 of Set 5 | chapar
# Processing Record 27 of Set 5 | houma
# Processing Record 28 of Set 5 | avera
# Processing Record 29 of Set 5 | mosquera
# Processing Record 30 of Set 5 | ndioum
# Processing Record 31 of Set 5 | chichli
# Processing Record 32 of Set 5 | pangody
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | sagaing
# Processing Record 37 of Set 5 | las varas
# Processing Record 38 of Set 5 | muros
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | irmo
# Processing Record 41 of Set 5 | morros
# Processing Record 42 of Set 5 | balkanabat
# Processing Record 43 of Set 5 | sedniv
# Processing Record 44 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | kayerkan
# Processing Record 46 of Set 5 | suhaia
# Processing Record 47 of Set 5 | puerto baquerizo moreno
# Processing Record 48 of Set 5 | abilene
# Processing Record 49 of Set 5 | muscat
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | chaupimarca
# Processing Record 2 of Set 6 | kenai
# Processing Record 3 of Set 6 | staryy nadym
# Processing Record 4 of Set 6 | taybad
# Processing Record 5 of Set 6 | thunder bay
# Processing Record 6 of Set 6 | karasjok
# Processing Record 7 of Set 6 | palmer
# Processing Record 8 of Set 6 | kasongo
# Processing Record 9 of Set 6 | la primavera
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 6 | nyurba
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | aksha
# Processing Record 18 of Set 6 | palmas
# Processing Record 19 of Set 6 | ambovombe
# Processing Record 20 of Set 6 | bosaso
# Processing Record 21 of Set 6 | klaebu
# Processing Record 22 of Set 6 | oranjemund
# Processing Record 23 of Set 6 | yaan
# Processing Record 24 of Set 6 | saint-joseph
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | torbay
# Processing Record 27 of Set 6 | kirakira
# Processing Record 28 of Set 6 | roald
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | chapais
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | kaili
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | khatanga
# Processing Record 38 of Set 6 | acapulco
# Processing Record 39 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 6 | talnakh
# Processing Record 43 of Set 6 | bira
# Processing Record 44 of Set 6 | amiens
# Processing Record 45 of Set 6 | camocim
# Processing Record 46 of Set 6 | tessalit
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | jasper
# Processing Record 49 of Set 6 | huanren
# Processing Record 50 of Set 6 | naryan-mar
# Processing Record 1 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 2 of Set 7 | yaroslavskiy
# Processing Record 3 of Set 7 | tuktoyaktuk
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | sioux lookout
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | nuuk
# Processing Record 9 of Set 7 | thompson
# Processing Record 10 of Set 7 | melville
# Processing Record 11 of Set 7 | cockburn town
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | sinnamary
# Processing Record 14 of Set 7 | sorland
# Processing Record 15 of Set 7 | nador
# Processing Record 16 of Set 7 | sijunjung
# Processing Record 17 of Set 7 | itaituba
# Processing Record 18 of Set 7 | rio grande
# Processing Record 19 of Set 7 | nchelenge
# Processing Record 20 of Set 7 | ambanja
# Processing Record 21 of Set 7 | zabol
# Processing Record 22 of Set 7 | north battleford
# Processing Record 23 of Set 7 | magnolia
# Processing Record 24 of Set 7 | tabou
# Processing Record 25 of Set 7 | oranjestad
# Processing Record 26 of Set 7 | qasigiannguit
# Processing Record 27 of Set 7 | aguacatan
# Processing Record 28 of Set 7 | taltal
# Processing Record 29 of Set 7 | kununurra
# Processing Record 30 of Set 7 | kibala
# Processing Record 31 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 7 | cidreira
# Processing Record 33 of Set 7 | mareeba
# Processing Record 34 of Set 7 | florida
# Processing Record 35 of Set 7 | mogadishu
# Processing Record 36 of Set 7 | bone
# Processing Record 37 of Set 7 | hovd
# Processing Record 38 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 7 | cacheu
# Processing Record 40 of Set 7 | turinsk
# Processing Record 41 of Set 7 | arucas
# Processing Record 42 of Set 7 | ostrovnoy
# Processing Record 43 of Set 7 | maindargi
# Processing Record 44 of Set 7 | hvide sande
# Processing Record 45 of Set 7 | jijiang
# Processing Record 46 of Set 7 | pemangkat
# Processing Record 47 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 7 | guatire
# Processing Record 49 of Set 7 | camacari
# Processing Record 50 of Set 7 | padang
# Processing Record 1 of Set 8 | thanatpin
# Processing Record 2 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 8 | svetlyy
# Processing Record 4 of Set 8 | bagdarin
# Processing Record 5 of Set 8 | mehamn
# Processing Record 6 of Set 8 | roma
# Processing Record 7 of Set 8 | kapitanivka
# Processing Record 8 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 8 | nykoping
# Processing Record 10 of Set 8 | mungwi
# Processing Record 11 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 8 | vanimo
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | ascension
# Processing Record 15 of Set 8 | gilgit
# Processing Record 16 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 8 | bani walid
# Processing Record 18 of Set 8 | chegdomyn
# Processing Record 19 of Set 8 | praia
# Processing Record 20 of Set 8 | calama
# Processing Record 21 of Set 8 | darhan
# Processing Record 22 of Set 8 | rawson
# Processing Record 23 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 24 of Set 8 | atikokan
# Processing Record 25 of Set 8 | gra liyia
# Processing Record 26 of Set 8 | tromso
# Processing Record 27 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 8 | fort nelson
# Processing Record 29 of Set 8 | sainte-rose
# Processing Record 30 of Set 8 | rincon
# Processing Record 31 of Set 8 | bat yam
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | kyren
# Processing Record 34 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 8 | conceicao do araguaia
# Processing Record 36 of Set 8 | baza
# Processing Record 37 of Set 8 | lar
# Processing Record 38 of Set 8 | jizan
# Processing Record 39 of Set 8 | grand gaube
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 42 of Set 8 | santa maria
# Processing Record 43 of Set 8 | xining
# Processing Record 44 of Set 8 | halenkov
# Processing Record 45 of Set 8 | vila do maio
# Processing Record 46 of Set 8 | thakurgaon
# Processing Record 47 of Set 8 | taoudenni
# Processing Record 48 of Set 8 | atlantic city
# Processing Record 49 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 8 | mecca
# Processing Record 1 of Set 9 | hov
# Processing Record 2 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 3 of Set 9 | luang prabang
# Processing Record 4 of Set 9 | devyatka
# City not found. Skipping...
# Processing Record 5 of Set 9 | panaba
# Processing Record 6 of Set 9 | nizwa
# Processing Record 7 of Set 9 | ballina
# Processing Record 8 of Set 9 | vila franca do campo
# Processing Record 9 of Set 9 | gorontalo
# Processing Record 10 of Set 9 | smithers
# Processing Record 11 of Set 9 | kota belud
# Processing Record 12 of Set 9 | brasilia
# Processing Record 13 of Set 9 | lodwar
# Processing Record 14 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 15 of Set 9 | dongying
# Processing Record 16 of Set 9 | panguna
# Processing Record 17 of Set 9 | vagur
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | mayo
# Processing Record 20 of Set 9 | belaya gora
# Processing Record 21 of Set 9 | yumen
# Processing Record 22 of Set 9 | baykit
# Processing Record 23 of Set 9 | champerico
# Processing Record 24 of Set 9 | narsaq
# Processing Record 25 of Set 9 | taquara
# Processing Record 26 of Set 9 | hastings
# Processing Record 27 of Set 9 | sarangani
# Processing Record 28 of Set 9 | cairns
# Processing Record 29 of Set 9 | hasaki
# Processing Record 30 of Set 9 | port augusta
# Processing Record 31 of Set 9 | atoyac
# Processing Record 32 of Set 9 | davila
# Processing Record 33 of Set 9 | thayetmyo
# Processing Record 34 of Set 9 | kurtalan
# Processing Record 35 of Set 9 | kiunga
# Processing Record 36 of Set 9 | sept-iles
# Processing Record 37 of Set 9 | meulaboh
# Processing Record 38 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 39 of Set 9 | poronaysk
# Processing Record 40 of Set 9 | filiatra
# Processing Record 41 of Set 9 | thohoyandou
# Processing Record 42 of Set 9 | mamallapuram
# Processing Record 43 of Set 9 | nelson bay
# Processing Record 44 of Set 9 | port blair
# Processing Record 45 of Set 9 | luganville
# Processing Record 46 of Set 9 | dunedin
# Processing Record 47 of Set 9 | loukhi
# Processing Record 48 of Set 9 | vaitape
# Processing Record 49 of Set 9 | puerto del rosario
# Processing Record 50 of Set 9 | tarare
# Processing Record 1 of Set 10 | muriwai beach
# Processing Record 2 of Set 10 | saint george
# Processing Record 3 of Set 10 | hualmay
# Processing Record 4 of Set 10 | san juan
# Processing Record 5 of Set 10 | nuevitas
# Processing Record 6 of Set 10 | cayenne
# Processing Record 7 of Set 10 | tazmalt
# Processing Record 8 of Set 10 | aljezur
# Processing Record 9 of Set 10 | ladushkin
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | heishan
# Processing Record 12 of Set 10 | kuna
# Processing Record 13 of Set 10 | nata
# Processing Record 14 of Set 10 | voh
# Processing Record 15 of Set 10 | havre-saint-pierre
# Processing Record 16 of Set 10 | manggar
# Processing Record 17 of Set 10 | pinawa
# Processing Record 18 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 19 of Set 10 | erdemli
# Processing Record 20 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 10 | mykhaylivka
# Processing Record 22 of Set 10 | navalmoral de la mata
# Processing Record 23 of Set 10 | biak
# Processing Record 24 of Set 10 | ternate
# Processing Record 25 of Set 10 | durres
# Processing Record 26 of Set 10 | peniche
# Processing Record 27 of Set 10 | neiafu
# Processing Record 28 of Set 10 | kamakhyanagar
# Processing Record 29 of Set 10 | qandala
# Processing Record 30 of Set 10 | tual
# Processing Record 31 of Set 10 | anuradhapura
# Processing Record 32 of Set 10 | chanika
# Processing Record 33 of Set 10 | millville
# Processing Record 34 of Set 10 | quatre cocos
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 10 | bud
# Processing Record 38 of Set 10 | morondava
# Processing Record 39 of Set 10 | juneau
# Processing Record 40 of Set 10 | ghorawal
# Processing Record 41 of Set 10 | concarneau
# Processing Record 42 of Set 10 | te anau
# Processing Record 43 of Set 10 | port lincoln
# Processing Record 44 of Set 10 | beyneu
# Processing Record 45 of Set 10 | luderitz
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | katherine
# Processing Record 48 of Set 10 | pocatello
# Processing Record 49 of Set 10 | byron bay
# Processing Record 50 of Set 10 | raga
# Processing Record 1 of Set 11 | lodeynoye pole
# Processing Record 2 of Set 11 | fairlie
# Processing Record 3 of Set 11 | basoko
# Processing Record 4 of Set 11 | qingyuan
# Processing Record 5 of Set 11 | foshan
# Processing Record 6 of Set 11 | musafirkhana
# Processing Record 7 of Set 11 | kovdor
# Processing Record 8 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 9 of Set 11 | vernon
# Processing Record 10 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 11 | kudahuvadhoo
# Processing Record 12 of Set 11 | hauterive
# Processing Record 13 of Set 11 | lichinga
# Processing Record 14 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 11 | tocopilla
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | isangel
# Processing Record 19 of Set 11 | achi
# Processing Record 20 of Set 11 | gairo
# Processing Record 21 of Set 11 | sisimiut
# Processing Record 22 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 11 | waipawa
# Processing Record 24 of Set 11 | soyo
# Processing Record 25 of Set 11 | bunia
# Processing Record 26 of Set 11 | mildura
# Processing Record 27 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 11 | moose factory
# Processing Record 29 of Set 11 | pilar
# Processing Record 30 of Set 11 | arman
# Processing Record 31 of Set 11 | platteville
# Processing Record 32 of Set 11 | uarini
# Processing Record 33 of Set 11 | hobe sound
# Processing Record 34 of Set 11 | luba
# Processing Record 35 of Set 11 | ust-nera
# Processing Record 36 of Set 11 | ulaangom
# Processing Record 37 of Set 11 | patu
# Processing Record 38 of Set 11 | port moresby
# Processing Record 39 of Set 11 | rudsar
# Processing Record 40 of Set 11 | tecpan
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | blackwater
# Processing Record 43 of Set 11 | batas
# Processing Record 44 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 11 | the hammocks
# Processing Record 47 of Set 11 | lumphat
# Processing Record 48 of Set 11 | mantamados
# Processing Record 49 of Set 11 | luwuk
# Processing Record 50 of Set 11 | lima
# Processing Record 1 of Set 12 | natal
# Processing Record 2 of Set 12 | kumluca
# Processing Record 3 of Set 12 | butler
# Processing Record 4 of Set 12 | walvis bay
# Processing Record 5 of Set 12 | baruun-urt
# Processing Record 6 of Set 12 | mendi
# Processing Record 7 of Set 12 | pokhara
# Processing Record 8 of Set 12 | olafsvik
# Processing Record 9 of Set 12 | adrar
# Processing Record 10 of Set 12 | maarianhamina
# Processing Record 11 of Set 12 | heidelberg
# Processing Record 12 of Set 12 | sooke
# Processing Record 13 of Set 12 | puerto escondido
# Processing Record 14 of Set 12 | omboue
# Processing Record 15 of Set 12 | puerto carreno
# Processing Record 16 of Set 12 | saharanpur
# Processing Record 17 of Set 12 | safaga
# Processing Record 18 of Set 12 | sabha
# Processing Record 19 of Set 12 | vysokogornyy
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | dalby
# Processing Record 22 of Set 12 | saint pete beach
# Processing Record 23 of Set 12 | panama city
# Processing Record 24 of Set 12 | lasa
# Processing Record 25 of Set 12 | yatou
# Processing Record 26 of Set 12 | nerchinskiy zavod
# Processing Record 27 of Set 12 | richards bay
# Processing Record 28 of Set 12 | ayan
# Processing Record 29 of Set 12 | dustlik
# Processing Record 30 of Set 12 | filadelfia
# Processing Record 31 of Set 12 | yining
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | porto novo
# Processing Record 34 of Set 12 | tarko-sale
# Processing Record 35 of Set 12 | astorga
# Processing Record 36 of Set 12 | sayyan
# Processing Record 37 of Set 12 | cururupu
# Processing Record 38 of Set 12 | gamba
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | sanbu
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | virginia beach
# Processing Record 43 of Set 12 | abhar
# Processing Record 44 of Set 12 | lashio
# Processing Record 45 of Set 12 | praia da vitoria
# Processing Record 46 of Set 12 | ravar
# Processing Record 47 of Set 12 | stony plain
# Processing Record 48 of Set 12 | thinadhoo
# Processing Record 49 of Set 12 | rapid valley
# Processing Record 50 of Set 12 | troitsko-pechorsk
# Processing Record 1 of Set 13 | lucapa
# Processing Record 2 of Set 13 | langsa
# Processing Record 3 of Set 13 | vazante
# Processing Record 4 of Set 13 | acari
# Processing Record 5 of Set 13 | srikakulam
# Processing Record 6 of Set 13 | dori
# Processing Record 7 of Set 13 | leo
# Processing Record 8 of Set 13 | salalah
# Processing Record 9 of Set 13 | itupiranga
# Processing Record 10 of Set 13 | simbahan
# Processing Record 11 of Set 13 | nagornskiy
# Processing Record 12 of Set 13 | posse
# Processing Record 13 of Set 13 | berezovyy
# Processing Record 14 of Set 13 | borogontsy
# Processing Record 15 of Set 13 | oskemen
# Processing Record 16 of Set 13 | coos bay
# Processing Record 17 of Set 13 | bousso
# Processing Record 18 of Set 13 | samfya
# Processing Record 19 of Set 13 | payson
# Processing Record 20 of Set 13 | porto recanati
# Processing Record 21 of Set 13 | skibbereen
# Processing Record 22 of Set 13 | bakel
# Processing Record 23 of Set 13 | adeje
# Processing Record 24 of Set 13 | burica
# City not found. Skipping...
# Processing Record 25 of Set 13 | saint-pierre
# Processing Record 26 of Set 13 | khorixas
# Processing Record 27 of Set 13 | emba
# Processing Record 28 of Set 13 | lake city
# Processing Record 29 of Set 13 | soligalich
# Processing Record 30 of Set 13 | lafia
# Processing Record 31 of Set 13 | muramvya
# Processing Record 32 of Set 13 | chifeng
# Processing Record 33 of Set 13 | bratsk
# Processing Record 34 of Set 13 | penzance
# Processing Record 35 of Set 13 | suntar
# Processing Record 36 of Set 13 | boditi
# Processing Record 37 of Set 13 | anchorage
# Processing Record 38 of Set 13 | tateyama
# Processing Record 39 of Set 13 | mugur-aksy
# Processing Record 40 of Set 13 | japura
# Processing Record 41 of Set 13 | chaumont
# Processing Record 42 of Set 13 | marzuq
# Processing Record 43 of Set 13 | coxim
# Processing Record 44 of Set 13 | yenagoa
# Processing Record 45 of Set 13 | san antonio
# Processing Record 46 of Set 13 | sarakhs
# Processing Record 47 of Set 13 | jaisalmer
# Processing Record 48 of Set 13 | maldonado
# Processing Record 49 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 13 | lata
# Processing Record 1 of Set 14 | kamenka
# Processing Record 2 of Set 14 | katobu
# Processing Record 3 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 4 of Set 14 | manado
# Processing Record 5 of Set 14 | bereda
# Processing Record 6 of Set 14 | bandarbeyla
# Processing Record 7 of Set 14 | beruwala
# Processing Record 8 of Set 14 | lyngseidet
# Processing Record 9 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 14 | touba
# Processing Record 11 of Set 14 | chumikan
# Processing Record 12 of Set 14 | bima
# Processing Record 13 of Set 14 | nishihara
# Processing Record 14 of Set 14 | batagay-alyta
# Processing Record 15 of Set 14 | mahajanga
# Processing Record 16 of Set 14 | burnie
# Processing Record 17 of Set 14 | goderich
# Processing Record 18 of Set 14 | mackay
# Processing Record 19 of Set 14 | asau
# Processing Record 20 of Set 14 | guhagar
# Processing Record 21 of Set 14 | anadyr
# Processing Record 22 of Set 14 | santa fe
# Processing Record 23 of Set 14 | capreol
# Processing Record 24 of Set 14 | copiapo
# Processing Record 25 of Set 14 | ahuimanu
# Processing Record 26 of Set 14 | shenandoah
# Processing Record 27 of Set 14 | matara
# Processing Record 28 of Set 14 | bundaberg
# Processing Record 29 of Set 14 | inhambane
# Processing Record 30 of Set 14 | calvinia
# Processing Record 31 of Set 14 | aykhal
# Processing Record 32 of Set 14 | pasighat
# Processing Record 33 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 34 of Set 14 | sakakah
# Processing Record 35 of Set 14 | yuanping
# Processing Record 36 of Set 14 | barhiya
# Processing Record 37 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 14 | goianesia
# Processing Record 39 of Set 14 | olinda
# Processing Record 40 of Set 14 | noyabrsk
# Processing Record 41 of Set 14 | metro
# Processing Record 42 of Set 14 | sur
# Processing Record 43 of Set 14 | jalu
# Processing Record 44 of Set 14 | amga
# Processing Record 45 of Set 14 | stonewall
# Processing Record 46 of Set 14 | pandan
# Processing Record 47 of Set 14 | veraval
# Processing Record 48 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 49 of Set 14 | alta floresta
# Processing Record 50 of Set 14 | nemuro
# Processing Record 1 of Set 15 | ust-barguzin
# Processing Record 2 of Set 15 | kupang
# Processing Record 3 of Set 15 | koumac
# Processing Record 4 of Set 15 | springbok
# Processing Record 5 of Set 15 | yanam
# Processing Record 6 of Set 15 | half moon bay
# Processing Record 7 of Set 15 | minna
# Processing Record 8 of Set 15 | tiarei
# Processing Record 9 of Set 15 | ayagoz
# Processing Record 10 of Set 15 | port-cartier
# Processing Record 11 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 15 | serra talhada
# Processing Record 13 of Set 15 | zhezkazgan
# Processing Record 14 of Set 15 | tibiao
# Processing Record 15 of Set 15 | beacon
# Processing Record 16 of Set 15 | itirapina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 654

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura -46.1927  168.8643     56.48        37          11
# 1       Carnarvon -24.8667  113.6333     93.27        33           0
# 2       Esperance -33.8667  121.9000     75.04        51           0
# 3    Punta Arenas -53.1500  -70.9167     42.91        70          40
# 4        Iracoubo   5.4802  -53.2011     75.31        91          99
# 5          Camalu  30.8500 -116.0667     53.42        82         100
# 6        Katsuura  35.1333  140.3000     46.51        55          46
# 7  Guerrero Negro  27.9769 -114.0611     61.68        74          23
# 8         Ushuaia -54.8000  -68.3000     40.66        75          40
# 9     New Norfolk -42.7826  147.0587     81.66        37          92
#
#    Wind Speed Country Current Description
# 0        5.39      NZ          few clouds
# 1       17.27      AU           clear sky
# 2        6.87      AU           clear sky
# 3       24.16      CL    scattered clouds
# 4        9.53      GF          light rain
# 5       10.56      MX     overcast clouds
# 6       11.05      JP    scattered clouds
# 7       10.33      MX          few clouds
# 8       28.77      AR    scattered clouds
# 9        3.60      AU     overcast clouds

# %%
city_data_df.keys()
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     56.48        37          11
# 1       Carnarvon      AU -24.8667  113.6333     93.27        33           0
# 2       Esperance      AU -33.8667  121.9000     75.04        51           0
# 3    Punta Arenas      CL -53.1500  -70.9167     42.91        70          40
# 4        Iracoubo      GF   5.4802  -53.2011     75.31        91          99
# 5          Camalu      MX  30.8500 -116.0667     53.42        82         100
# 6        Katsuura      JP  35.1333  140.3000     46.51        55          46
# 7  Guerrero Negro      MX  27.9769 -114.0611     61.68        74          23
# 8         Ushuaia      AR -54.8000  -68.3000     40.66        75          40
# 9     New Norfolk      AU -42.7826  147.0587     81.66        37          92
#
#    Wind Speed Current Description
# 0        5.39          few clouds
# 1       17.27           clear sky
# 2        6.87           clear sky
# 3       24.16    scattered clouds
# 4        9.53          light rain
# 5       10.56     overcast clouds
# 6       11.05    scattered clouds
# 7       10.33          few clouds
# 8       28.77    scattered clouds
# 9        3.60     overcast clouds

# %%
len(city_data_df)
# Out:
# 654

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# To get an output from a function, we need to call the function with the correct number of parameters 
# or arguments for the function.

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(0,-40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-25,15))

# %%
from scipy.stats import linregress
linregress(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

# %%
(slope, intercept, rval, pval, stderr) = linregress(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

# %%
line_eq = "y = " +  str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

# %%
r_value = str(round(rval,2))
print(r_value)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(30,30))

# %%
linregress(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-55,11))

# %%
linregress(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,27))

# %%
linregress(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,30))

# %%
linregress(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])
